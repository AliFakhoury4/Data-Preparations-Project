# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import os

pd.options.mode.chained_assignment = None
seed = 321

# %%
rice = pd.read_csv('Rice_Cammeo_Osmancik.csv')

print(rice.isnull().sum())

rice
# Out:
# Area                 109
# Perimeter            105
# Major_Axis_Length    130
# Minor_Axis_Length    109
# Eccentricity         126
# Convex_Area          117
# Extent               120
# Class                114
# dtype: int64
#          Area   Perimeter  Major_Axis_Length  Minor_Axis_Length  Eccentricity  \
# 0     15231.0  525.578979         229.749878          85.093788      0.928882
# 1     14656.0  494.311005         206.020065          91.730972      0.895405
# 2     14634.0  501.122009         214.106781          87.768288      0.912118
# 3     13176.0  458.342987         193.337387          87.448395      0.891861
# 4     14688.0  507.166992         211.743378          89.312454      0.906691
# ...       ...         ...                ...                ...           ...
# 3805  11441.0  415.858002         170.486771          85.756592      0.864280
# 3806  11625.0  421.390015         167.714798          89.462570      0.845850
# ...

# %%
def detect_outliers(data):
    outliers=[]

    threshold = 3
    mean = np.mean(data)
    std = np.std(data)

    for i in data:
        z_score = (i-mean)/std
        if np.abs(z_score) > threshold:
            outliers.append(i)

    return outliers

# %%
outliersArea = detect_outliers(rice["Area"])
outliersPerimeter = detect_outliers(rice["Perimeter"])
outliersMajorAxisLength = detect_outliers(rice["Major_Axis_Length"])
outliersMinorAxisLength = detect_outliers(rice["Minor_Axis_Length"])
outliersEccentricity = detect_outliers(rice["Eccentricity"])
outliersConvexArea = detect_outliers(rice["Convex_Area"])
outliersExtent = detect_outliers(rice["Extent"])
